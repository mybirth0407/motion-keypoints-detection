# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils import data as data_utils
from torchvision import datasets, models, transforms

from sklearn.model_selection import KFold, train_test_split

import albumentations as A
import albumentations_experimental as AE
from albumentations.pytorch import ToTensorV2
import cv2
from tqdm import tqdm

# Some basic setup:
# Setup detectron2 logger
import detectron2
from detectron2.utils.logger import setup_logger
setup_logger()

# import some common libraries
import numpy as np
import os, json, cv2, random, sys
import pandas as pd
import time
import copy

# import some common detectron2 utilities
from detectron2 import model_zoo
from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg
from detectron2.utils.visualizer import Visualizer
from detectron2.data import MetadataCatalog, DatasetCatalog
from detectron2.engine import DefaultTrainer

from detectron2.evaluation import COCOEvaluator, inference_on_dataset
from detectron2.data import build_detection_test_loader

# Connect your script to Neptune
# import neptune
# import neptune_config

from detectron2.structures import BoxMode
# Out:
# ** fvcore version of PathManager will be deprecated soon. **
# ** Please migrate to the version in iopath repo. **
# https://github.com/facebookresearch/iopath

# %%
class Trainer(DefaultTrainer):
    """
    We use the "DefaultTrainer" which contains a number pre-defined logic for
    standard training workflow. They may not work for you, especially if you
    are working on a new research project. In that case you can use the cleaner
    "SimpleTrainer", or write your own training loop.
    """

    @classmethod
    def build_evaluator(cls, cfg, dataset_name, output_folder=None):
        """
        Create evaluator(s) for a given dataset.
        This uses the special metadata "evaluator_type" associated with each builtin dataset.
        For your own dataset, you can simply create an evaluator manually in your
        script and do not have to worry about the hacky if-else logic here.
        """
        if output_folder is None:
            output_folder = os.path.join(cfg.OUTPUT_DIR, "inference")
        evaluator_list = []
        evaluator_type = MetadataCatalog.get(dataset_name).evaluator_type
        if evaluator_type in ["coco", "coco_panoptic_seg"]:
            evaluator_list.append(COCOEvaluator(dataset_name, cfg, True, output_folder))
        if len(evaluator_list) == 0:
            raise NotImplementedError(
                "no Evaluator for the dataset {} with the type {}".format(
                    dataset_name, evaluator_type
                )
            )
        if len(evaluator_list) == 1:
            return evaluator_list[0]
        return DatasetEvaluators(evaluator_list)

# %%
def train_val_split(imgs, keypoints, random_state=42):
    d = dict()
    for file in imgs:
        key = ''.join(file.split('-')[:-1])
        if key not in d.keys():
            d[key] = [file]
        else:
            d[key].append(file)
            
    np.random.seed(random_state)
    trains = []
    validations = []
    for key, value in d.items():
        r = np.random.randint(len(value), size=2)
        for i in range(len(value)):
            if i in r:
                validations.append(np.where(imgs == value[i])[0][0])
            else:
                trains.append(np.where(imgs == value[i])[0][0])
    return (
        imgs[trains], imgs[validations],
        keypoints[trains], keypoints[validations]
    )

# %%
def train_val_split2(augmented, train):
    train_imgs = train.iloc[:, 0].to_numpy()
    train_keypoints = train.iloc[:, 1:].to_numpy()
    aug_imgs = augmented.iloc[:, 0].to_numpy()
    aug_keypoints = augmented.iloc[:, 1:].to_numpy()
    return aug_imgs, train_imgs, aug_keypoints, train_keypoints

# %%
def get_data_dicts(data_dir, imgs, keypoints, phase):
#     train_dir = os.path.join(data_dir, "augmented" if phase=="train" else "train_imgs")
    train_dir = os.path.join(data_dir, "train_imgs")
    dataset_dicts = []

    for idx, item in tqdm(enumerate(zip(imgs, keypoints))):
        img, keypoint = item[0], item[1]

        record = {}
        filepath = os.path.join(train_dir, img)
        record["height"], record["width"] = cv2.imread(filepath).shape[:2]
        record["file_name"] = filepath
        record["image_id"] = idx

        keypoints_v = []
        for i, keypoint_ in enumerate(keypoint):
            keypoints_v.append(keypoint_) # if coco set, should be added 0.5
            if i % 2 == 1:
                keypoints_v.append(2)

        x = keypoint[0::2]
        y = keypoint[1::2]
        x_min, x_max = min(x), max(x)
        y_min, y_max = min(y), max(y)

        obj = {
            "bbox": [x_min, y_min, x_max, y_max],
            "bbox_mode": BoxMode.XYXY_ABS,
            "category_id": 0,
            "keypoints": keypoints_v
        }

        record["annotations"] = [obj]
        dataset_dicts.append(record)
    return dataset_dicts

# %%
data_dir = "../data/"
# aug_df = pd.read_csv(os.path.join(data_dir, "augmented.csv"))
train_df = pd.read_csv(os.path.join(data_dir, "train_df_modified.csv"))

keypoint_names = train_df.columns.to_list()[1:]
keypoint_flip_map = []
for i in range(0, len(keypoint_names) // 2, 2):
    keypoint_flip_map.append((keypoint_names[i], keypoint_names[i+1]))

columns = train_df.columns[1:].to_list()[::2]
keypoint_names = [
    label.replace("_x", '').replace("_y", '') for label in columns
]

# %%
imgs = train_df.iloc[:, 0].to_numpy()
keypoints = train_df.iloc[:, 1:].to_numpy()
imgs_train, imgs_val, keypoints_train, keypoints_val = \
    train_val_split(imgs, keypoints, random_state=42)

imgs_d = {
    "train": imgs_train,
    "val": imgs_val
}
keypoints_d = {
    "train": keypoints_train,
    "val": keypoints_val
}

for d in ["train", "val"]:
    DatasetCatalog.register(
        "keypoints_" + d,
        lambda d=d: get_data_dicts(
            data_dir, imgs_d[d], keypoints_d[d], phase=d
        )
    )
    MetadataCatalog.get("keypoints_" + d).set(
        thing_classes=["human"]
    )
    MetadataCatalog.get("keypoints_" + d).set(
        keypoint_names=keypoint_names
    )
    MetadataCatalog.get("keypoints_" + d).set(
        keypoint_flip_map=keypoint_flip_map
    )
    MetadataCatalog.get("keypoints_" + d).set(
        evaluator_type="coco"
    )

motions_metadata = MetadataCatalog.get("keypoints_train")
print(motions_metadata)
# Out:
# Metadata(evaluator_type='coco', keypoint_flip_map=[('nose_x', 'nose_y'), ('left_eye_x', 'left_eye_y'), ('right_eye_x', 'right_eye_y'), ('left_ear_x', 'left_ear_y'), ('right_ear_x', 'right_ear_y'), ('left_shoulder_x', 'left_shoulder_y'), ('right_shoulder_x', 'right_shoulder_y'), ('left_elbow_x', 'left_elbow_y'), ('right_elbow_x', 'right_elbow_y'), ('left_wrist_x', 'left_wrist_y'), ('right_wrist_x', 'right_wrist_y'), ('left_hip_x', 'left_hip_y')], keypoint_names=['nose', 'left_eye', 'right_eye', 'left_ear', 'right_ear', 'left_shoulder', 'right_shoulder', 'left_elbow', 'right_elbow', 'left_wrist', 'right_wrist', 'left_hip', 'right_hip', 'left_knee', 'right_knee', 'left_ankle', 'right_ankle', 'neck', 'left_palm', 'right_palm', 'spine2(back)', 'spine1(waist)', 'left_instep', 'right_instep'], name='keypoints_train', thing_classes=['human'])

# %%
# keypoint_rcnn_R_50_FPN_3x.yaml
# keypoint_rcnn_X_101_32x8d_FPN_3x.yaml
cfg = get_cfg()
cfg.merge_from_file(model_zoo.get_config_file("COCO-Keypoints/keypoint_rcnn_X_101_32x8d_FPN_3x.yaml"))
cfg.DATASETS.TRAIN = ("keypoints_train",)
cfg.DATASETS.TEST = ("keypoints_val",)
cfg.DATALOADER.NUM_WORKERS = 0
cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url("COCO-Keypoints/keypoint_rcnn_X_101_32x8d_FPN_3x.yaml")  # Let training initialize from model zoo
cfg.SOLVER.IMS_PER_BATCH = 2
# cfg.SOLVER.BASE_LR = 0.00025  # pick a good LR
cfg.SOLVER.BASE_LR = 0.001  # pick a good LR
cfg.SOLVER.MAX_ITER = 5000    # 300 iterations seems good enough for this toy dataset; you will need to train longer for a practical dataset
cfg.SOLVER.STEPS = []         # do not decay learning rate
cfg.MODEL.ROI_HEADS.BATCH_SIZE_PER_IMAGE = 256   # faster, and good enough for this toy dataset (default: 512)
cfg.MODEL.ROI_HEADS.NUM_CLASSES = 1  # only has one class (ballon). (see https://detectron2.readthedocs.io/tutorials/datasets.html#update-the-config-for-new-datasets)
cfg.MODEL.ROI_KEYPOINT_HEAD.NUM_KEYPOINTS = 24
# NOTE: this config means the number of classes, but a few popular unofficial tutorials incorrect uses num_classes+1 here.

cfg.TEST.KEYPOINT_OKS_SIGMAS = kpt_oks_sigmas=np.ones((24, 1), dtype=float).tolist()
cfg.TEST.EVAL_PERIOD = 500

# %%
# evaluator = COCOEvaluator("keypoints_val", ("bbox", "keypoints"), False, output_dir="./output/", kpt_oks_sigmas=np.ones((24, 1), dtype=float).tolist())

# %%
os.makedirs(cfg.OUTPUT_DIR, exist_ok=True)
trainer = Trainer(cfg)
trainer.resume_or_load(resume=False)
trainer.train()
# trainer.test(model=trainer.model, cfg=cfg, evaluators=evaluator)

# trainer.test(cfg, trainer.model)
# Out:
# [03/24 19:00:43 d2.engine.defaults]: Model:
# GeneralizedRCNN(
#   (backbone): FPN(
#     (fpn_lateral2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral3): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelMaxPool()
#     (bottom_up): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#       )
#       (res2): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#       )
#       (res3): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#       )
#       (res4): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (4): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (5): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (6): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (7): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (8): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (9): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (10): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (11): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (12): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (13): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (14): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (15): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (16): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (17): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (18): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (19): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (20): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (21): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (22): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#       )
#       (res5): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             2048, 2048, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             2048, 2048, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             2048, 2048, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#       )
#     )
#   )
#   (proposal_generator): RPN(
#     (rpn_head): StandardRPNHead(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (objectness_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#   )
#   (roi_heads): StandardROIHeads(
#     (box_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(7, 7), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(7, 7), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(7, 7), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (box_head): FastRCNNConvFCHead(
#       (fc1): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#     )
#     (box_predictor): FastRCNNOutputLayers(
#       (cls_score): Linear(in_features=1024, out_features=2, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=4, bias=True)
#     )
#     (keypoint_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(14, 14), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(14, 14), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(14, 14), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(14, 14), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (keypoint_head): KRCNNConvDeconvUpsampleHead(
#       (conv_fcn1): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv_fcn2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv_fcn3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv_fcn4): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv_fcn5): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv_fcn6): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv_fcn7): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv_fcn8): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (score_lowres): ConvTranspose2d(512, 24, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     )
#   )
# )
# 3660it [01:14, 49.28it/s]
# [03/24 19:01:57 d2.data.build]: Removed 0 images with no usable annotations. 3660 images left.
# [03/24 19:01:57 d2.data.build]: Removed 0 images with fewer than 1 keypoints.
# [03/24 19:01:58 d2.data.build]: Distribution of instances among all 1 categories:
# |  category  | #instances   |
# |:----------:|:-------------|
# |   human    | 3660         |
# |            |              |
# [03/24 19:01:58 d2.data.common]: Serializing 3660 elements to byte tensors and concatenating them all ...
# [03/24 19:01:58 d2.data.common]: Serialized dataset takes 4.75 MiB
# [03/24 19:01:58 d2.data.dataset_mapper]: Augmentations used in training: [ResizeShortestEdge(short_edge_length=(640, 672, 704, 736, 768, 800), max_size=1333, sample_style='choice'), RandomFlip()]
# [03/24 19:01:58 d2.data.build]: Using training sampler TrainingSampler
# Skip loading parameter 'roi_heads.keypoint_head.score_lowres.weight' to the model due to incompatible shapes: (512, 17, 4, 4) in the checkpoint but (512, 24, 4, 4) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.keypoint_head.score_lowres.bias' to the model due to incompatible shapes: (17,) in the checkpoint but (24,) in the model! You might want to double check if this is expected.
# [03/24 19:01:59 d2.engine.train_loop]: Starting training from iteration 0
# d:\gdrive\workspace\detectron2-windows\detectron2\layers\wrappers.py:226: UserWarning: This overload of nonzero is deprecated:
# 	nonzero()
# Consider using one of the following signatures instead:
# 	nonzero(*, bool as_tuple) (Triggered internally at  ..\torch\csrc\utils\python_arg_parser.cpp:766.)
#   return x.nonzero().unbind(1)
# [03/24 19:02:32 d2.utils.events]:  eta: 2:15:49  iter: 19  total_loss: 8.357  loss_cls: 0.079  loss_box_reg: 0.094  loss_keypoint: 8.186  loss_rpn_cls: 0.000  loss_rpn_loc: 0.004  time: 1.6294  data_time: 0.1867  lr: 0.000020  max_mem: 6125M
# [03/24 19:03:04 d2.utils.events]:  eta: 2:15:44  iter: 39  total_loss: 8.377  loss_cls: 0.080  loss_box_reg: 0.102  loss_keypoint: 8.196  loss_rpn_cls: 0.001  loss_rpn_loc: 0.005  time: 1.6219  data_time: 0.1884  lr: 0.000040  max_mem: 6230M
# [03/24 19:03:37 d2.utils.events]:  eta: 2:16:07  iter: 59  total_loss: 8.258  loss_cls: 0.074  loss_box_reg: 0.089  loss_keypoint: 8.065  loss_rpn_cls: 0.000  loss_rpn_loc: 0.005  time: 1.6305  data_time: 0.1874  lr: 0.000060  max_mem: 6230M
# [03/24 19:04:09 d2.utils.events]:  eta: 2:15:44  iter: 79  total_loss: 8.138  loss_cls: 0.055  loss_box_reg: 0.076  loss_keypoint: 8.014  loss_rpn_cls: 0.000  loss_rpn_loc: 0.004  time: 1.6247  data_time: 0.1879  lr: 0.000080  max_mem: 6230M
# [03/24 19:04:41 d2.utils.events]:  eta: 2:14:54  iter: 99  total_loss: 8.014  loss_cls: 0.055  loss_box_reg: 0.065  loss_keypoint: 7.879  loss_rpn_cls: 0.001  loss_rpn_loc: 0.004  time: 1.6141  data_time: 0.1865  lr: 0.000100  max_mem: 6230M
# [03/24 19:05:14 d2.utils.events]:  eta: 2:14:42  iter: 119  total_loss: 7.848  loss_cls: 0.037  loss_box_reg: 0.046  loss_keypoint: 7.753  loss_rpn_cls: 0.000  loss_rpn_loc: 0.004  time: 1.6187  data_time: 0.1898  lr: 0.000120  max_mem: 6230M
# [03/24 19:05:47 d2.utils.events]:  eta: 2:14:24  iter: 139  total_loss: 7.637  loss_cls: 0.043  loss_box_reg: 0.039  loss_keypoint: 7.568  loss_rpn_cls: 0.000  loss_rpn_loc: 0.003  time: 1.6239  data_time: 0.1904  lr: 0.000140  max_mem: 6230M
# [03/24 19:06:20 d2.utils.events]:  eta: 2:14:16  iter: 159  total_loss: 7.251  loss_cls: 0.033  loss_box_reg: 0.045  loss_keypoint: 7.193  loss_rpn_cls: 0.000  loss_rpn_loc: 0.003  time: 1.6268  data_time: 0.1889  lr: 0.000160  max_mem: 6230M
# [03/24 19:06:52 d2.utils.events]:  eta: 2:13:38  iter: 179  total_loss: 6.721  loss_cls: 0.029  loss_box_reg: 0.036  loss_keypoint: 6.631  loss_rpn_cls: 0.001  loss_rpn_loc: 0.003  time: 1.6272  data_time: 0.1886  lr: 0.000180  max_mem: 6230M
# [03/24 19:07:24 d2.utils.events]:  eta: 2:13:00  iter: 199  total_loss: 6.065  loss_cls: 0.033  loss_box_reg: 0.045  loss_keypoint: 5.970  loss_rpn_cls: 0.000  loss_rpn_loc: 0.003  time: 1.6241  data_time: 0.1878  lr: 0.000200  max_mem: 6255M
# [03/24 19:07:57 d2.utils.events]:  eta: 2:12:37  iter: 219  total_loss: 5.393  loss_cls: 0.025  loss_box_reg: 0.039  loss_keypoint: 5.328  loss_rpn_cls: 0.000  loss_rpn_loc: 0.003  time: 1.6246  data_time: 0.1878  lr: 0.000220  max_mem: 6281M
# [03/24 19:08:31 d2.utils.events]:  eta: 2:12:38  iter: 239  total_loss: 5.254  loss_cls: 0.027  loss_box_reg: 0.030  loss_keypoint: 5.195  loss_rpn_cls: 0.000  loss_rpn_loc: 0.003  time: 1.6304  data_time: 0.1874  lr: 0.000240  max_mem: 6281M
# [03/24 19:09:03 d2.utils.events]:  eta: 2:12:08  iter: 259  total_loss: 5.021  loss_cls: 0.031  loss_box_reg: 0.033  loss_keypoint: 4.953  loss_rpn_cls: 0.000  loss_rpn_loc: 0.003  time: 1.6305  data_time: 0.1867  lr: 0.000260  max_mem: 6289M
# [03/24 19:09:37 d2.utils.events]:  eta: 2:11:44  iter: 279  total_loss: 4.963  loss_cls: 0.025  loss_box_reg: 0.032  loss_keypoint: 4.895  loss_rpn_cls: 0.000  loss_rpn_loc: 0.003  time: 1.6326  data_time: 0.1891  lr: 0.000280  max_mem: 6298M
# [03/24 19:10:10 d2.utils.events]:  eta: 2:11:20  iter: 299  total_loss: 4.711  loss_cls: 0.024  loss_box_reg: 0.024  loss_keypoint: 4.644  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 1.6352  data_time: 0.1896  lr: 0.000300  max_mem: 6298M
# [03/24 19:10:42 d2.utils.events]:  eta: 2:10:42  iter: 319  total_loss: 4.371  loss_cls: 0.024  loss_box_reg: 0.021  loss_keypoint: 4.322  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 1.6327  data_time: 0.1870  lr: 0.000320  max_mem: 6298M
# [03/24 19:11:15 d2.utils.events]:  eta: 2:10:13  iter: 339  total_loss: 4.527  loss_cls: 0.024  loss_box_reg: 0.033  loss_keypoint: 4.443  loss_rpn_cls: 0.000  loss_rpn_loc: 0.003  time: 1.6331  data_time: 0.1887  lr: 0.000340  max_mem: 6298M
# [03/24 19:11:48 d2.utils.events]:  eta: 2:09:42  iter: 359  total_loss: 4.367  loss_cls: 0.021  loss_box_reg: 0.031  loss_keypoint: 4.316  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 1.6332  data_time: 0.1871  lr: 0.000360  max_mem: 6298M
# [03/24 19:12:20 d2.utils.events]:  eta: 2:09:12  iter: 379  total_loss: 4.221  loss_cls: 0.020  loss_box_reg: 0.027  loss_keypoint: 4.169  loss_rpn_cls: 0.000  loss_rpn_loc: 0.003  time: 1.6323  data_time: 0.1860  lr: 0.000380  max_mem: 6298M
# [03/24 19:12:53 d2.utils.events]:  eta: 2:08:38  iter: 399  total_loss: 4.118  loss_cls: 0.019  loss_box_reg: 0.028  loss_keypoint: 4.085  loss_rpn_cls: 0.000  loss_rpn_loc: 0.003  time: 1.6324  data_time: 0.1871  lr: 0.000400  max_mem: 6306M
# [03/24 19:13:26 d2.utils.events]:  eta: 2:08:07  iter: 419  total_loss: 4.170  loss_cls: 0.020  loss_box_reg: 0.024  loss_keypoint: 4.131  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 1.6334  data_time: 0.1875  lr: 0.000420  max_mem: 6306M
# [03/24 19:13:58 d2.utils.events]:  eta: 2:07:41  iter: 439  total_loss: 4.323  loss_cls: 0.019  loss_box_reg: 0.024  loss_keypoint: 4.279  loss_rpn_cls: 0.001  loss_rpn_loc: 0.004  time: 1.6332  data_time: 0.1893  lr: 0.000440  max_mem: 6306M
# [03/24 19:14:32 d2.utils.events]:  eta: 2:07:10  iter: 459  total_loss: 4.046  loss_cls: 0.017  loss_box_reg: 0.025  loss_keypoint: 3.990  loss_rpn_cls: 0.000  loss_rpn_loc: 0.003  time: 1.6349  data_time: 0.1890  lr: 0.000460  max_mem: 6306M
# [03/24 19:15:05 d2.utils.events]:  eta: 2:06:37  iter: 479  total_loss: 4.225  loss_cls: 0.016  loss_box_reg: 0.020  loss_keypoint: 4.172  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 1.6356  data_time: 0.1885  lr: 0.000480  max_mem: 6306M
# 512it [00:10, 49.35it/s]
# [03/24 19:15:48 d2.data.build]: Distribution of instances among all 1 categories:
# |  category  | #instances   |
# |:----------:|:-------------|
# |   human    | 512          |
# |            |              |
# [03/24 19:15:48 d2.data.common]: Serializing 512 elements to byte tensors and concatenating them all ...
# [03/24 19:15:48 d2.data.common]: Serialized dataset takes 0.66 MiB
# [03/24 19:15:48 d2.data.dataset_mapper]: Augmentations used in training: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [03/24 19:15:48 d2.evaluation.coco_evaluation]: 'keypoints_val' is not registered by `register_coco_instances`. Therefore trying to convert it to COCO format ...
# WARNING [03/24 19:15:48 d2.data.datasets.coco]: Using previously cached COCO format annotations at './output\inference\keypoints_val_coco_format.json'. You need to clear the cache file if your dataset has been modified.
# [03/24 19:15:48 d2.evaluation.evaluator]: Start inference on 512 images
# [03/24 19:15:52 d2.evaluation.evaluator]: Inference done 11/512. 0.2415 s / img. ETA=0:02:41
# [03/24 19:15:57 d2.evaluation.evaluator]: Inference done 26/512. 0.2437 s / img. ETA=0:02:43
# [03/24 19:16:02 d2.evaluation.evaluator]: Inference done 41/512. 0.2442 s / img. ETA=0:02:40
# [03/24 19:16:08 d2.evaluation.evaluator]: Inference done 56/512. 0.2443 s / img. ETA=0:02:35
# [03/24 19:16:13 d2.evaluation.evaluator]: Inference done 71/512. 0.2442 s / img. ETA=0:02:30
# [03/24 19:16:18 d2.evaluation.evaluator]: Inference done 86/512. 0.2438 s / img. ETA=0:02:25
# [03/24 19:16:23 d2.evaluation.evaluator]: Inference done 101/512. 0.2437 s / img. ETA=0:02:19
# [03/24 19:16:28 d2.evaluation.evaluator]: Inference done 116/512. 0.2435 s / img. ETA=0:02:14
# [03/24 19:16:33 d2.evaluation.evaluator]: Inference done 131/512. 0.2435 s / img. ETA=0:02:09
# [03/24 19:16:38 d2.evaluation.evaluator]: Inference done 146/512. 0.2435 s / img. ETA=0:02:04
# [03/24 19:16:43 d2.evaluation.evaluator]: Inference done 161/512. 0.2439 s / img. ETA=0:01:58
# [03/24 19:16:48 d2.evaluation.evaluator]: Inference done 176/512. 0.2439 s / img. ETA=0:01:53
# [03/24 19:16:53 d2.evaluation.evaluator]: Inference done 191/512. 0.2438 s / img. ETA=0:01:48
# [03/24 19:16:58 d2.evaluation.evaluator]: Inference done 206/512. 0.2440 s / img. ETA=0:01:43
# [03/24 19:17:03 d2.evaluation.evaluator]: Inference done 221/512. 0.2439 s / img. ETA=0:01:38
# [03/24 19:17:08 d2.evaluation.evaluator]: Inference done 236/512. 0.2440 s / img. ETA=0:01:33
# [03/24 19:17:14 d2.evaluation.evaluator]: Inference done 250/512. 0.2440 s / img. ETA=0:01:29
# [03/24 19:17:19 d2.evaluation.evaluator]: Inference done 265/512. 0.2440 s / img. ETA=0:01:23
# [03/24 19:17:24 d2.evaluation.evaluator]: Inference done 280/512. 0.2443 s / img. ETA=0:01:18
# [03/24 19:17:29 d2.evaluation.evaluator]: Inference done 295/512. 0.2442 s / img. ETA=0:01:13
# [03/24 19:17:34 d2.evaluation.evaluator]: Inference done 310/512. 0.2443 s / img. ETA=0:01:08
# [03/24 19:17:39 d2.evaluation.evaluator]: Inference done 325/512. 0.2442 s / img. ETA=0:01:03
# [03/24 19:17:44 d2.evaluation.evaluator]: Inference done 340/512. 0.2443 s / img. ETA=0:00:58
# [03/24 19:17:49 d2.evaluation.evaluator]: Inference done 355/512. 0.2445 s / img. ETA=0:00:53
# [03/24 19:17:54 d2.evaluation.evaluator]: Inference done 370/512. 0.2446 s / img. ETA=0:00:48
# [03/24 19:17:59 d2.evaluation.evaluator]: Inference done 385/512. 0.2446 s / img. ETA=0:00:43
# [03/24 19:18:05 d2.evaluation.evaluator]: Inference done 400/512. 0.2448 s / img. ETA=0:00:38
# [03/24 19:18:10 d2.evaluation.evaluator]: Inference done 415/512. 0.2448 s / img. ETA=0:00:33
# [03/24 19:18:15 d2.evaluation.evaluator]: Inference done 430/512. 0.2448 s / img. ETA=0:00:27
# [03/24 19:18:20 d2.evaluation.evaluator]: Inference done 445/512. 0.2448 s / img. ETA=0:00:22
# [03/24 19:18:25 d2.evaluation.evaluator]: Inference done 460/512. 0.2449 s / img. ETA=0:00:17
# [03/24 19:18:30 d2.evaluation.evaluator]: Inference done 475/512. 0.2450 s / img. ETA=0:00:12
# [03/24 19:18:35 d2.evaluation.evaluator]: Inference done 490/512. 0.2450 s / img. ETA=0:00:07
# [03/24 19:18:40 d2.evaluation.evaluator]: Inference done 505/512. 0.2451 s / img. ETA=0:00:02
# [03/24 19:18:43 d2.evaluation.evaluator]: Total inference time: 0:02:52.557166 (0.340349 s / img per device, on 1 devices)
# [03/24 19:18:43 d2.evaluation.evaluator]: Total inference pure compute time: 0:02:04 (0.245075 s / img per device, on 1 devices)
# [03/24 19:18:43 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [03/24 19:18:43 d2.evaluation.coco_evaluation]: Saving results to ./output\inference\coco_instances_results.json
# [03/24 19:18:43 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 0.05 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.00 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.844
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.990
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.844
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.880
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.880
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.880
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.880
# [03/24 19:18:43 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs  |  APm  |  APl   |
# |:------:|:------:|:------:|:-----:|:-----:|:------:|
# | 84.393 | 99.969 | 98.975 |  nan  |  nan  | 84.393 |
# [03/24 19:18:43 d2.evaluation.coco_evaluation]: Some metrics cannot be computed and is shown as NaN.
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *keypoints*
# COCOeval_opt.evaluate() finished in 0.06 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.00 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 1.000
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 1.000
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 1.000
# [03/24 19:18:43 d2.evaluation.coco_evaluation]: Evaluation results for keypoints:
# |   AP   |  AP50  |  AP75  |  APm  |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|
# | 99.969 | 99.969 | 99.969 |  nan  | 99.969 |
# [03/24 19:18:43 d2.evaluation.coco_evaluation]: Some metrics cannot be computed and is shown as NaN.
# [03/24 19:18:43 d2.engine.defaults]: Evaluation results for keypoints_val in csv format:
# [03/24 19:18:43 d2.evaluation.testing]: copypaste: Task: bbox
# [03/24 19:18:43 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [03/24 19:18:43 d2.evaluation.testing]: copypaste: 84.3933,99.9693,98.9749,nan,nan,84.3933
# [03/24 19:18:43 d2.evaluation.testing]: copypaste: Task: keypoints
# [03/24 19:18:43 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APm,APl
# [03/24 19:18:43 d2.evaluation.testing]: copypaste: 99.9693,99.9693,99.9693,nan,99.9693
# [03/24 19:18:43 d2.utils.events]:  eta: 2:06:05  iter: 499  total_loss: 3.924  loss_cls: 0.020  loss_box_reg: 0.017  loss_keypoint: 3.879  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 1.6365  data_time: 0.1885  lr: 0.000500  max_mem: 6306M
# [03/24 19:19:16 d2.utils.events]:  eta: 2:05:33  iter: 519  total_loss: 3.909  loss_cls: 0.018  loss_box_reg: 0.021  loss_keypoint: 3.863  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 1.6362  data_time: 0.1875  lr: 0.000519  max_mem: 6306M
# [03/24 19:19:48 d2.utils.events]:  eta: 2:05:00  iter: 539  total_loss: 4.171  loss_cls: 0.021  loss_box_reg: 0.025  loss_keypoint: 4.128  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 1.6364  data_time: 0.1873  lr: 0.000539  max_mem: 6306M
# [03/24 19:20:21 d2.utils.events]:  eta: 2:04:29  iter: 559  total_loss: 3.838  loss_cls: 0.024  loss_box_reg: 0.021  loss_keypoint: 3.763  loss_rpn_cls: 0.000  loss_rpn_loc: 0.003  time: 1.6370  data_time: 0.1881  lr: 0.000559  max_mem: 6315M
# [03/24 19:20:55 d2.utils.events]:  eta: 2:03:59  iter: 579  total_loss: 3.883  loss_cls: 0.017  loss_box_reg: 0.020  loss_keypoint: 3.851  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 1.6380  data_time: 0.1884  lr: 0.000579  max_mem: 6315M
# [03/24 19:21:28 d2.utils.events]:  eta: 2:03:26  iter: 599  total_loss: 3.669  loss_cls: 0.015  loss_box_reg: 0.016  loss_keypoint: 3.610  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 1.6379  data_time: 0.1881  lr: 0.000599  max_mem: 6315M
# [03/24 19:22:01 d2.utils.events]:  eta: 2:02:57  iter: 619  total_loss: 3.816  loss_cls: 0.019  loss_box_reg: 0.024  loss_keypoint: 3.768  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 1.6384  data_time: 0.1872  lr: 0.000619  max_mem: 6315M
# [03/24 19:22:34 d2.utils.events]:  eta: 2:02:18  iter: 639  total_loss: 3.709  loss_cls: 0.012  loss_box_reg: 0.017  loss_keypoint: 3.689  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 1.6386  data_time: 0.1866  lr: 0.000639  max_mem: 6315M
# [03/24 19:23:07 d2.utils.events]:  eta: 2:01:49  iter: 659  total_loss: 3.428  loss_cls: 0.013  loss_box_reg: 0.016  loss_keypoint: 3.399  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 1.6393  data_time: 0.1873  lr: 0.000659  max_mem: 6315M
# [03/24 19:23:40 d2.utils.events]:  eta: 2:01:17  iter: 679  total_loss: 3.457  loss_cls: 0.013  loss_box_reg: 0.015  loss_keypoint: 3.420  loss_rpn_cls: 0.000  loss_rpn_loc: 0.003  time: 1.6400  data_time: 0.1881  lr: 0.000679  max_mem: 6315M
# [03/24 19:24:13 d2.utils.events]:  eta: 2:00:44  iter: 699  total_loss: 3.765  loss_cls: 0.022  loss_box_reg: 0.022  loss_keypoint: 3.714  loss_rpn_cls: 0.000  loss_rpn_loc: 0.003  time: 1.6406  data_time: 0.1887  lr: 0.000699  max_mem: 6358M
# [03/24 19:24:46 d2.utils.events]:  eta: 2:00:16  iter: 719  total_loss: 3.812  loss_cls: 0.015  loss_box_reg: 0.016  loss_keypoint: 3.783  loss_rpn_cls: 0.000  loss_rpn_loc: 0.003  time: 1.6411  data_time: 0.1880  lr: 0.000719  max_mem: 6358M
# [03/24 19:25:20 d2.utils.events]:  eta: 1:59:43  iter: 739  total_loss: 3.566  loss_cls: 0.016  loss_box_reg: 0.017  loss_keypoint: 3.532  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 1.6414  data_time: 0.1963  lr: 0.000739  max_mem: 6358M
# [03/24 19:25:53 d2.utils.events]:  eta: 1:59:10  iter: 759  total_loss: 3.462  loss_cls: 0.016  loss_box_reg: 0.013  loss_keypoint: 3.421  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 1.6423  data_time: 0.1988  lr: 0.000759  max_mem: 6375M
# [03/24 19:26:26 d2.utils.events]:  eta: 1:58:38  iter: 779  total_loss: 3.878  loss_cls: 0.021  loss_box_reg: 0.020  loss_keypoint: 3.811  loss_rpn_cls: 0.000  loss_rpn_loc: 0.003  time: 1.6424  data_time: 0.1986  lr: 0.000779  max_mem: 6375M
# [03/24 19:26:59 d2.utils.events]:  eta: 1:58:06  iter: 799  total_loss: 3.579  loss_cls: 0.018  loss_box_reg: 0.016  loss_keypoint: 3.523  loss_rpn_cls: 0.000  loss_rpn_loc: 0.003  time: 1.6426  data_time: 0.1934  lr: 0.000799  max_mem: 6375M
# [03/24 19:27:32 d2.utils.events]:  eta: 1:57:34  iter: 819  total_loss: 3.823  loss_cls: 0.022  loss_box_reg: 0.025  loss_keypoint: 3.760  loss_rpn_cls: 0.000  loss_rpn_loc: 0.003  time: 1.6433  data_time: 0.1950  lr: 0.000819  max_mem: 6375M
# [03/24 19:28:06 d2.utils.events]:  eta: 1:57:01  iter: 839  total_loss: 3.593  loss_cls: 0.017  loss_box_reg: 0.023  loss_keypoint: 3.556  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 1.6441  data_time: 0.2184  lr: 0.000839  max_mem: 6392M
# [03/24 19:28:40 d2.utils.events]:  eta: 1:56:30  iter: 859  total_loss: 3.447  loss_cls: 0.016  loss_box_reg: 0.022  loss_keypoint: 3.408  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 1.6449  data_time: 0.2162  lr: 0.000859  max_mem: 6392M
# [03/24 19:29:14 d2.utils.events]:  eta: 1:56:01  iter: 879  total_loss: 3.517  loss_cls: 0.018  loss_box_reg: 0.023  loss_keypoint: 3.470  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 1.6467  data_time: 0.2155  lr: 0.000879  max_mem: 6392M
# [03/24 19:29:48 d2.utils.events]:  eta: 1:55:31  iter: 899  total_loss: 3.325  loss_cls: 0.020  loss_box_reg: 0.022  loss_keypoint: 3.273  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 1.6475  data_time: 0.2150  lr: 0.000899  max_mem: 6392M
# [03/24 19:30:22 d2.utils.events]:  eta: 1:55:01  iter: 919  total_loss: 3.640  loss_cls: 0.016  loss_box_reg: 0.021  loss_keypoint: 3.601  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 1.6484  data_time: 0.2171  lr: 0.000919  max_mem: 6392M
# [03/24 19:30:55 d2.utils.events]:  eta: 1:54:29  iter: 939  total_loss: 3.467  loss_cls: 0.021  loss_box_reg: 0.019  loss_keypoint: 3.411  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 1.6492  data_time: 0.2133  lr: 0.000939  max_mem: 6392M
# [03/24 19:31:28 d2.utils.events]:  eta: 1:53:56  iter: 959  total_loss: 3.384  loss_cls: 0.017  loss_box_reg: 0.017  loss_keypoint: 3.339  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 1.6493  data_time: 0.2049  lr: 0.000959  max_mem: 6392M
# [03/24 19:32:02 d2.utils.events]:  eta: 1:53:22  iter: 979  total_loss: 3.475  loss_cls: 0.019  loss_box_reg: 0.020  loss_keypoint: 3.404  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 1.6497  data_time: 0.2036  lr: 0.000979  max_mem: 6392M
# 512it [00:10, 47.15it/s]
# [03/24 19:32:46 d2.data.common]: Serializing 512 elements to byte tensors and concatenating them all ...
# [03/24 19:32:46 d2.data.common]: Serialized dataset takes 0.66 MiB
# [03/24 19:32:46 d2.data.dataset_mapper]: Augmentations used in training: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [03/24 19:32:46 d2.evaluation.evaluator]: Start inference on 512 images
# [03/24 19:32:50 d2.evaluation.evaluator]: Inference done 11/512. 0.2415 s / img. ETA=0:02:41
# [03/24 19:32:55 d2.evaluation.evaluator]: Inference done 26/512. 0.2434 s / img. ETA=0:02:43
# [03/24 19:33:00 d2.evaluation.evaluator]: Inference done 41/512. 0.2433 s / img. ETA=0:02:39
# [03/24 19:33:05 d2.evaluation.evaluator]: Inference done 56/512. 0.2437 s / img. ETA=0:02:34
# [03/24 19:33:10 d2.evaluation.evaluator]: Inference done 71/512. 0.2436 s / img. ETA=0:02:29
# [03/24 19:33:15 d2.evaluation.evaluator]: Inference done 86/512. 0.2434 s / img. ETA=0:02:24
# [03/24 19:33:20 d2.evaluation.evaluator]: Inference done 101/512. 0.2443 s / img. ETA=0:02:19
# [03/24 19:33:26 d2.evaluation.evaluator]: Inference done 116/512. 0.2442 s / img. ETA=0:02:14
# [03/24 19:33:31 d2.evaluation.evaluator]: Inference done 131/512. 0.2440 s / img. ETA=0:02:09
# [03/24 19:33:36 d2.evaluation.evaluator]: Inference done 146/512. 0.2440 s / img. ETA=0:02:03
# [03/24 19:33:41 d2.evaluation.evaluator]: Inference done 161/512. 0.2445 s / img. ETA=0:01:58
# [03/24 19:33:46 d2.evaluation.evaluator]: Inference done 176/512. 0.2444 s / img. ETA=0:01:53
# [03/24 19:33:51 d2.evaluation.evaluator]: Inference done 191/512. 0.2444 s / img. ETA=0:01:48
# [03/24 19:33:56 d2.evaluation.evaluator]: Inference done 206/512. 0.2443 s / img. ETA=0:01:43
# [03/24 19:34:01 d2.evaluation.evaluator]: Inference done 221/512. 0.2443 s / img. ETA=0:01:38
# [03/24 19:34:06 d2.evaluation.evaluator]: Inference done 236/512. 0.2446 s / img. ETA=0:01:33
# ...
# COCOeval_opt.accumulate() finished in 0.00 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 1.000
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 1.000
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 1.000
# [03/24 21:33:39 d2.evaluation.coco_evaluation]: Evaluation results for keypoints:
# |   AP    |  AP50   |  AP75   |  APm  |   APl   |
# |:-------:|:-------:|:-------:|:-----:|:-------:|
# | 100.000 | 100.000 | 100.000 |  nan  | 100.000 |
# [03/24 21:33:39 d2.evaluation.coco_evaluation]: Some metrics cannot be computed and is shown as NaN.
# [03/24 21:33:39 d2.engine.defaults]: Evaluation results for keypoints_val in csv format:
# [03/24 21:33:39 d2.evaluation.testing]: copypaste: Task: bbox
# [03/24 21:33:39 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [03/24 21:33:39 d2.evaluation.testing]: copypaste: 90.5800,100.0000,100.0000,nan,nan,90.5800
# [03/24 21:33:39 d2.evaluation.testing]: copypaste: Task: keypoints
# [03/24 21:33:39 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APm,APl
# [03/24 21:33:39 d2.evaluation.testing]: copypaste: 100.0000,100.0000,100.0000,nan,100.0000
# [03/24 21:33:39 d2.utils.events]:  eta: 0:14:10  iter: 4499  total_loss: 2.416  loss_cls: 0.012  loss_box_reg: 0.011  loss_keypoint: 2.393  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 1.6515  data_time: 0.1881  lr: 0.001000  max_mem: 6392M
# [03/24 21:34:11 d2.utils.events]:  eta: 0:13:35  iter: 4519  total_loss: 2.589  loss_cls: 0.013  loss_box_reg: 0.010  loss_keypoint: 2.561  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 1.6513  data_time: 0.1881  lr: 0.001000  max_mem: 6392M
# [03/24 21:34:43 d2.utils.events]:  eta: 0:13:01  iter: 4539  total_loss: 2.572  loss_cls: 0.012  loss_box_reg: 0.011  loss_keypoint: 2.534  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 1.6512  data_time: 0.1873  lr: 0.001000  max_mem: 6392M
# [03/24 21:35:16 d2.utils.events]:  eta: 0:12:27  iter: 4559  total_loss: 2.283  loss_cls: 0.013  loss_box_reg: 0.009  loss_keypoint: 2.251  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 1.6512  data_time: 0.1900  lr: 0.001000  max_mem: 6392M
# [03/24 21:35:50 d2.utils.events]:  eta: 0:11:54  iter: 4579  total_loss: 2.540  loss_cls: 0.012  loss_box_reg: 0.008  loss_keypoint: 2.519  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 1.6513  data_time: 0.1891  lr: 0.001000  max_mem: 6392M
# [03/24 21:36:22 d2.utils.events]:  eta: 0:11:20  iter: 4599  total_loss: 2.508  loss_cls: 0.010  loss_box_reg: 0.011  loss_keypoint: 2.488  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 1.6511  data_time: 0.1867  lr: 0.001000  max_mem: 6392M
# [03/24 21:36:55 d2.utils.events]:  eta: 0:10:46  iter: 4619  total_loss: 2.784  loss_cls: 0.011  loss_box_reg: 0.010  loss_keypoint: 2.739  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 1.6511  data_time: 0.1870  lr: 0.001000  max_mem: 6392M
# [03/24 21:37:28 d2.utils.events]:  eta: 0:10:12  iter: 4639  total_loss: 2.656  loss_cls: 0.011  loss_box_reg: 0.010  loss_keypoint: 2.634  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 1.6510  data_time: 0.1862  lr: 0.001000  max_mem: 6392M
# [03/24 21:38:02 d2.utils.events]:  eta: 0:09:38  iter: 4659  total_loss: 2.695  loss_cls: 0.012  loss_box_reg: 0.014  loss_keypoint: 2.666  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 1.6512  data_time: 0.1887  lr: 0.001000  max_mem: 6392M
# [03/24 21:38:35 d2.utils.events]:  eta: 0:09:04  iter: 4679  total_loss: 2.472  loss_cls: 0.015  loss_box_reg: 0.013  loss_keypoint: 2.441  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 1.6513  data_time: 0.1860  lr: 0.001000  max_mem: 6392M
# [03/24 21:39:08 d2.utils.events]:  eta: 0:08:30  iter: 4699  total_loss: 2.206  loss_cls: 0.013  loss_box_reg: 0.011  loss_keypoint: 2.184  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 1.6513  data_time: 0.1878  lr: 0.001000  max_mem: 6392M
# [03/24 21:39:41 d2.utils.events]:  eta: 0:07:56  iter: 4719  total_loss: 2.408  loss_cls: 0.014  loss_box_reg: 0.011  loss_keypoint: 2.367  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 1.6513  data_time: 0.1870  lr: 0.001000  max_mem: 6392M
# [03/24 21:40:14 d2.utils.events]:  eta: 0:07:22  iter: 4739  total_loss: 2.283  loss_cls: 0.014  loss_box_reg: 0.009  loss_keypoint: 2.263  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 1.6512  data_time: 0.1870  lr: 0.001000  max_mem: 6392M
# [03/24 21:40:47 d2.utils.events]:  eta: 0:06:48  iter: 4759  total_loss: 2.859  loss_cls: 0.016  loss_box_reg: 0.014  loss_keypoint: 2.809  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 1.6512  data_time: 0.1886  lr: 0.001000  max_mem: 6392M
# [03/24 21:41:19 d2.utils.events]:  eta: 0:06:14  iter: 4779  total_loss: 2.460  loss_cls: 0.011  loss_box_reg: 0.010  loss_keypoint: 2.445  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 1.6510  data_time: 0.1886  lr: 0.001000  max_mem: 6392M
# [03/24 21:41:53 d2.utils.events]:  eta: 0:05:40  iter: 4799  total_loss: 2.768  loss_cls: 0.014  loss_box_reg: 0.013  loss_keypoint: 2.724  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 1.6511  data_time: 0.1870  lr: 0.001000  max_mem: 6392M
# [03/24 21:42:26 d2.utils.events]:  eta: 0:05:06  iter: 4819  total_loss: 2.419  loss_cls: 0.010  loss_box_reg: 0.012  loss_keypoint: 2.391  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 1.6512  data_time: 0.1880  lr: 0.001000  max_mem: 6392M
# [03/24 21:42:59 d2.utils.events]:  eta: 0:04:33  iter: 4839  total_loss: 2.402  loss_cls: 0.012  loss_box_reg: 0.011  loss_keypoint: 2.383  loss_rpn_cls: 0.000  loss_rpn_loc: 0.001  time: 1.6512  data_time: 0.1885  lr: 0.001000  max_mem: 6392M
# [03/24 21:43:33 d2.utils.events]:  eta: 0:03:59  iter: 4859  total_loss: 2.246  loss_cls: 0.010  loss_box_reg: 0.009  loss_keypoint: 2.208  loss_rpn_cls: 0.000  loss_rpn_loc: 0.001  time: 1.6513  data_time: 0.1899  lr: 0.001000  max_mem: 6392M
# [03/24 21:44:05 d2.utils.events]:  eta: 0:03:25  iter: 4879  total_loss: 2.338  loss_cls: 0.011  loss_box_reg: 0.013  loss_keypoint: 2.320  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 1.6512  data_time: 0.1911  lr: 0.001000  max_mem: 6392M
# [03/24 21:44:38 d2.utils.events]:  eta: 0:02:51  iter: 4899  total_loss: 2.422  loss_cls: 0.014  loss_box_reg: 0.011  loss_keypoint: 2.386  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 1.6512  data_time: 0.1895  lr: 0.001000  max_mem: 6392M
# [03/24 21:45:11 d2.utils.events]:  eta: 0:02:17  iter: 4919  total_loss: 2.309  loss_cls: 0.013  loss_box_reg: 0.009  loss_keypoint: 2.282  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 1.6512  data_time: 0.1908  lr: 0.001000  max_mem: 6392M
# [03/24 21:45:45 d2.utils.events]:  eta: 0:01:43  iter: 4939  total_loss: 2.364  loss_cls: 0.013  loss_box_reg: 0.010  loss_keypoint: 2.333  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 1.6513  data_time: 0.1888  lr: 0.001000  max_mem: 6392M
# [03/24 21:46:18 d2.utils.events]:  eta: 0:01:09  iter: 4959  total_loss: 2.473  loss_cls: 0.012  loss_box_reg: 0.009  loss_keypoint: 2.452  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 1.6514  data_time: 0.1889  lr: 0.001000  max_mem: 6392M
# [03/24 21:46:51 d2.utils.events]:  eta: 0:00:35  iter: 4979  total_loss: 2.595  loss_cls: 0.012  loss_box_reg: 0.009  loss_keypoint: 2.572  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 1.6514  data_time: 0.1883  lr: 0.001000  max_mem: 6392M
# 512it [00:10, 46.81it/s]
# [03/24 21:47:41 d2.data.common]: Serializing 512 elements to byte tensors and concatenating them all ...
# [03/24 21:47:41 d2.data.common]: Serialized dataset takes 0.66 MiB
# [03/24 21:47:41 d2.data.dataset_mapper]: Augmentations used in training: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [03/24 21:47:41 d2.evaluation.evaluator]: Start inference on 512 images
# [03/24 21:47:45 d2.evaluation.evaluator]: Inference done 11/512. 0.2480 s / img. ETA=0:02:46
# [03/24 21:47:50 d2.evaluation.evaluator]: Inference done 26/512. 0.2463 s / img. ETA=0:02:47
# [03/24 21:47:55 d2.evaluation.evaluator]: Inference done 41/512. 0.2459 s / img. ETA=0:02:42
# [03/24 21:48:00 d2.evaluation.evaluator]: Inference done 56/512. 0.2460 s / img. ETA=0:02:38
# [03/24 21:48:06 d2.evaluation.evaluator]: Inference done 71/512. 0.2460 s / img. ETA=0:02:33
# [03/24 21:48:11 d2.evaluation.evaluator]: Inference done 86/512. 0.2460 s / img. ETA=0:02:27
# [03/24 21:48:16 d2.evaluation.evaluator]: Inference done 101/512. 0.2459 s / img. ETA=0:02:22
# [03/24 21:48:21 d2.evaluation.evaluator]: Inference done 116/512. 0.2460 s / img. ETA=0:02:17
# [03/24 21:48:26 d2.evaluation.evaluator]: Inference done 131/512. 0.2458 s / img. ETA=0:02:11
# [03/24 21:48:32 d2.evaluation.evaluator]: Inference done 146/512. 0.2460 s / img. ETA=0:02:06
# [03/24 21:48:37 d2.evaluation.evaluator]: Inference done 161/512. 0.2459 s / img. ETA=0:02:01
# [03/24 21:48:42 d2.evaluation.evaluator]: Inference done 176/512. 0.2464 s / img. ETA=0:01:56
# [03/24 21:48:47 d2.evaluation.evaluator]: Inference done 191/512. 0.2464 s / img. ETA=0:01:51
# [03/24 21:48:52 d2.evaluation.evaluator]: Inference done 206/512. 0.2463 s / img. ETA=0:01:45
# [03/24 21:48:58 d2.evaluation.evaluator]: Inference done 221/512. 0.2465 s / img. ETA=0:01:40
# [03/24 21:49:03 d2.evaluation.evaluator]: Inference done 236/512. 0.2464 s / img. ETA=0:01:35
# [03/24 21:49:08 d2.evaluation.evaluator]: Inference done 251/512. 0.2465 s / img. ETA=0:01:30
# [03/24 21:49:13 d2.evaluation.evaluator]: Inference done 266/512. 0.2464 s / img. ETA=0:01:24
# [03/24 21:49:18 d2.evaluation.evaluator]: Inference done 281/512. 0.2465 s / img. ETA=0:01:19
# [03/24 21:49:23 d2.evaluation.evaluator]: Inference done 296/512. 0.2465 s / img. ETA=0:01:14
# [03/24 21:49:28 d2.evaluation.evaluator]: Inference done 311/512. 0.2465 s / img. ETA=0:01:09
# [03/24 21:49:33 d2.evaluation.evaluator]: Inference done 326/512. 0.2465 s / img. ETA=0:01:04
# [03/24 21:49:38 d2.evaluation.evaluator]: Inference done 341/512. 0.2464 s / img. ETA=0:00:58
# [03/24 21:49:44 d2.evaluation.evaluator]: Inference done 356/512. 0.2465 s / img. ETA=0:00:53
# [03/24 21:49:49 d2.evaluation.evaluator]: Inference done 371/512. 0.2465 s / img. ETA=0:00:48
# [03/24 21:49:54 d2.evaluation.evaluator]: Inference done 386/512. 0.2465 s / img. ETA=0:00:43
# [03/24 21:49:59 d2.evaluation.evaluator]: Inference done 401/512. 0.2465 s / img. ETA=0:00:38
# [03/24 21:50:04 d2.evaluation.evaluator]: Inference done 416/512. 0.2466 s / img. ETA=0:00:33
# [03/24 21:50:09 d2.evaluation.evaluator]: Inference done 431/512. 0.2466 s / img. ETA=0:00:27
# [03/24 21:50:14 d2.evaluation.evaluator]: Inference done 446/512. 0.2466 s / img. ETA=0:00:22
# [03/24 21:50:20 d2.evaluation.evaluator]: Inference done 461/512. 0.2469 s / img. ETA=0:00:17
# [03/24 21:50:25 d2.evaluation.evaluator]: Inference done 476/512. 0.2470 s / img. ETA=0:00:12
# [03/24 21:50:30 d2.evaluation.evaluator]: Inference done 491/512. 0.2470 s / img. ETA=0:00:07
# [03/24 21:50:35 d2.evaluation.evaluator]: Inference done 506/512. 0.2470 s / img. ETA=0:00:02
# [03/24 21:50:37 d2.evaluation.evaluator]: Total inference time: 0:02:54.280344 (0.343748 s / img per device, on 1 devices)
# [03/24 21:50:37 d2.evaluation.evaluator]: Total inference pure compute time: 0:02:05 (0.246988 s / img per device, on 1 devices)
# [03/24 21:50:37 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [03/24 21:50:37 d2.evaluation.coco_evaluation]: Saving results to ./output\inference\coco_instances_results.json
# [03/24 21:50:37 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 0.11 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.00 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.921
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.921
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.941
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.941
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.941
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.941
# [03/24 21:50:37 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs  |  APm  |  APl   |
# |:------:|:------:|:------:|:-----:|:-----:|:------:|
# | 92.094 | 99.998 | 99.998 |  nan  |  nan  | 92.094 |
# [03/24 21:50:37 d2.evaluation.coco_evaluation]: Some metrics cannot be computed and is shown as NaN.
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *keypoints*
# COCOeval_opt.evaluate() finished in 0.06 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.00 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 1.000
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 1.000
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 1.000
# [03/24 21:50:37 d2.evaluation.coco_evaluation]: Evaluation results for keypoints:
# |   AP   |  AP50  |  AP75  |  APm  |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|
# | 99.998 | 99.998 | 99.998 |  nan  | 99.998 |
# [03/24 21:50:37 d2.evaluation.coco_evaluation]: Some metrics cannot be computed and is shown as NaN.
# [03/24 21:50:37 d2.engine.defaults]: Evaluation results for keypoints_val in csv format:
# [03/24 21:50:37 d2.evaluation.testing]: copypaste: Task: bbox
# [03/24 21:50:37 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [03/24 21:50:37 d2.evaluation.testing]: copypaste: 92.0941,99.9981,99.9981,nan,nan,92.0941
# [03/24 21:50:37 d2.evaluation.testing]: copypaste: Task: keypoints
# [03/24 21:50:37 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APm,APl
# [03/24 21:50:37 d2.evaluation.testing]: copypaste: 99.9981,99.9981,99.9981,nan,99.9981
# [03/24 21:50:37 d2.utils.events]:  eta: 0:00:01  iter: 4999  total_loss: 2.562  loss_cls: 0.011  loss_box_reg: 0.010  loss_keypoint: 2.508  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 1.6514  data_time: 0.1883  lr: 0.001000  max_mem: 6392M
# [03/24 21:50:37 d2.engine.hooks]: Overall training speed: 4997 iterations in 2:17:33 (1.6517 s / it)
# [03/24 21:50:37 d2.engine.hooks]: Total training time: 2:48:34 (0:31:00 on hooks)

# %%
# Inference should use the config with parameters that are used in training
# cfg now already contains everything we've set previously. We changed it a little bit for inference:
cfg.MODEL.WEIGHTS = os.path.join(cfg.OUTPUT_DIR, "model_final.pth")  # path to the model we just trained
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.7   # set a custom testing threshold
predictor = DefaultPredictor(cfg)

preds = []
files = []
test_dir = os.path.join(data_dir, "test_imgs")
test_list = os.listdir(test_dir)
test_list.sort()
except_list = []
for file in tqdm(test_list):
    filepath = os.path.join(test_dir, file)
    # print(filepath)
    im = cv2.imread(filepath)
    outputs = predictor(im)
    outputs = outputs["instances"].to("cpu").get("pred_keypoints").numpy()
    files.append(file)
    pred = []
    try:
        for out in outputs[0]:
            pred.extend([float(e) for e in out[:2]])
    except:
        except_list.append(filepath)
        print(filepath)
    preds.append(pred)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1600/1600 [08:11<00:00,  3.25it/s]

# %%
df_sub = pd.read_csv(f"../data/sample_submission.csv")
df = pd.DataFrame(columns=df_sub.columns)
df["image"] = files
df.iloc[:, 1:] = preds

df.to_csv(f"submissions.csv", index=False)

# %%
print(1)
# Out:
# 1
